# %% [markdown]
# <a href="https://colab.research.google.com/github/OC-46/cs417-participation/blob/main/type_hint.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# %%writefile type_hint.py
import mypy

a: int = 1
b: int = 3
c: int = 5

def add(a: int, b: int) -> float:
  a + b
  return a + b




print(a)
print(b)
print(c)
print(add(a, b))
# Out:
# Overwriting type_hint.py

# %%
# !pip install mypy
# !mypy type_hint.py
# Out:
# ...
# Success: no issues found in 1 source file
